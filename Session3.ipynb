# %% [markdown]
# Session 3 - Sector-Wise Domestic Savings (At Current Prices)
#
# Dataset: RBI Handbook of Statistics on Indian States
# Goal: Learn how to inspect, filter, sort and summarise a real dataset using Pandas.
#
# .sector wise domestic saving
# Non-financial corporations
# financial corporations
# general government
# household sector

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\abhis\Downloads\data acj\UDISE_2023-24_Table_2.1.csv')

# %%
df.columns = df.columns.str.replace(" ", "_")
df.columns = df.columns.str.replace("-", "_")
df.columns = df.columns.str.lower()
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:,.2f}'.format

# %%
df.head()
# Out:
#    sl._no.               india/state/ut  total_number_of___schools  \
# 0        1                        India                    1471891
# 1        2  Andaman and Nicobar Islands                        412
# 2        3               Andhra Pradesh                      61373
# 3        4            Arunachal Pradesh                       3490
# 4        5                        Assam                      56630
#
#    total_number_of___enrolments  total_number_of___teachers  \
# 0                     248045828                     9807600
# 1                         72119                        5750
# 2                       8741885                      338293
# 3                        323717                       24700
# 4                       6922533                      342199
#
#    percentage_share_of_schools_by_category___primary  \
# 0                                              50.00
# 1                                              50.70
# ...

# %%
df.tail(5)
# Out:
#     sl._no. india/state/ut  total_number_of___schools  \
# 32       33      Telangana                      42901
# 33       34        Tripura                       4923
# 34       35  Uttar Pradesh                     255087
# 35       36    Uttarakhand                      22551
# 36       37    West Bengal                      93945
#
#     total_number_of___enrolments  total_number_of___teachers  \
# 32                       7293644                      341460
# 33                        689408                       37661
# 34                      41662794                     1538479
# 35                       2372400                      130741
# 36                      18015525                      576557
#
#     percentage_share_of_schools_by_category___primary  \
# 32                                              47.90
# 33                                              50.20
# 34                                              52.30
# ...
